# %%
import pandas as pd

# %%
dt = pd.read_csv('C:/Users/MAHIMA TUMMALA/WebstormProjects/untitled/scatter_plot/data/adult.csv')

# %%
dt.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country  income  median_income  \
# 0          4356              40  United-States  130762         114158
# ...

# %%
avg_cols  = dt.groupby(['race', 'sex'])['income'].mean()

# %%
avg_cols
# Out:
# race                sex
# Amer-Indian-Eskimo  Female    118429.878049
#                     Male      122274.166667
# Asian-Pac-Islander  Female    113914.142857
#                     Male      116307.017699
# Black               Female    112056.488479
#                     Male      111363.303327
# Other               Female    119146.178571
#                     Male      122387.627907
# White               Female    113088.687256
#                     Male      113404.556355
# Name: income, dtype: float64

# %%
avg_cols.to_json('C:/Users/MAHIMA TUMMALA/WebstormProjects/untitled/scatter_plot/data/race_sex1.json')
